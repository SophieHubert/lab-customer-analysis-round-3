# %% [markdown]
# # Lab | Customer Analysis Round 3

# %% [markdown]
# For this lab, we still keep using the `marketing_customer_analysis.csv` file. You can find the file in the `files_for_lab` folder.
#
# ### Get the data
#
# - Use the same jupyter file from the last lab, `Customer Analysis Round 3`
#
# ### EDA (Exploratory Data Analysis) - Complete the following tasks to explore the data:

# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('marketing_customer_analysis.csv')

# %%
data = data.rename(columns={'Customer':'Customer ID',
                         'EmploymentStatus': 'Employment Status'})

data
# Out:
#        Unnamed: 0 Customer ID       State  Customer Lifetime Value Response  \
# 0               0     DK49336     Arizona              4809.216960       No
# 1               1     KX64629  California              2228.525238       No
# 2               2     LZ68649  Washington             14947.917300       No
# 3               3     XL78013      Oregon             22332.439460      Yes
# 4               4     QA50777      Oregon              9025.067525       No
# ...           ...         ...         ...                      ...      ...
# 10905       10905     FE99816      Nevada             15563.369440       No
# 10906       10906     KX53892      Oregon              5259.444853       No
# 10907       10907     TL39050     Arizona             23893.304100       No
# 10908       10908     WA60547  California             11971.977650       No
# 10909       10909     IV32877         NaN              6857.519928      NaN
#
# ...

# %%
data.dropna()
# Out:
#        Unnamed: 0 Customer ID       State  Customer Lifetime Value Response  \
# 2               2     LZ68649  Washington             14947.917300       No
# 3               3     XL78013      Oregon             22332.439460      Yes
# 10             10     HG93801     Arizona              5154.764074       No
# 13             13     KR82385  California              5454.587929       No
# 16             16     FH51383  California              5326.677654       No
# ...           ...         ...         ...                      ...      ...
# 10902       10902     PP30874  California              3579.023825       No
# 10903       10903     SU71163     Arizona              2771.663013       No
# 10904       10904     QI63521      Nevada             19228.463620       No
# 10906       10906     KX53892      Oregon              5259.444853       No
# 10908       10908     WA60547  California             11971.977650       No
#
# ...

# %%
data
# Out:
#        Unnamed: 0 Customer ID       State  Customer Lifetime Value Response  \
# 0               0     DK49336     Arizona              4809.216960       No
# 1               1     KX64629  California              2228.525238       No
# 2               2     LZ68649  Washington             14947.917300       No
# 3               3     XL78013      Oregon             22332.439460      Yes
# 4               4     QA50777      Oregon              9025.067525       No
# ...           ...         ...         ...                      ...      ...
# 10905       10905     FE99816      Nevada             15563.369440       No
# 10906       10906     KX53892      Oregon              5259.444853       No
# 10907       10907     TL39050     Arizona             23893.304100       No
# 10908       10908     WA60547  California             11971.977650       No
# 10909       10909     IV32877         NaN              6857.519928      NaN
#
# ...

# %% [markdown]
# ## 1. Show DataFrame info.

# %%
data.head()
# Out:
#    Unnamed: 0 Customer ID       State  Customer Lifetime Value Response  \
# 0           0     DK49336     Arizona              4809.216960       No
# 1           1     KX64629  California              2228.525238       No
# 2           2     LZ68649  Washington             14947.917300       No
# 3           3     XL78013      Oregon             22332.439460      Yes
# 4           4     QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date Employment Status Gender  ...  \
# 0     Basic   College           2/18/11          Employed      M  ...
# 1     Basic   College           1/18/11        Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11          Employed      M  ...
# 3  Extended   College           1/11/11          Employed      M  ...
# 4   Premium  Bachelor           1/17/11     Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %% [markdown]
# ## 2. Describe DataFrame.

# %%
data.describe().T 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     10910 non-null  int64
#  1   Customer ID                    10910 non-null  object
#  2   State                          10279 non-null  object
#  3   Customer Lifetime Value        10910 non-null  float64
#  4   Response                       10279 non-null  object
#  5   Coverage                       10910 non-null  object
#  6   Education                      10910 non-null  object
#  7   Effective To Date              10910 non-null  object
#  8   Employment Status              10910 non-null  object
#  9   Gender                         10910 non-null  object
#  10  Income                         10910 non-null  int64
#  11  Location Code                  10910 non-null  object
# ...

# %% [markdown]
# ## 3. How a plot of the total number of responses.

# %%
data['Response'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['Response'].value_counts()
# Out:
# No     8813
# Yes    1466
# Name: Response, dtype: int64

# %% [markdown]
# ## 4. Show a plot of the response rate by the sales channel.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None) 
import warnings
warnings.filterwarnings('ignore') 


data
# Out:
#        Unnamed: 0 Customer ID       State  Customer Lifetime Value Response  \
# 0               0     DK49336     Arizona              4809.216960       No
# 1               1     KX64629  California              2228.525238       No
# 2               2     LZ68649  Washington             14947.917300       No
# 3               3     XL78013      Oregon             22332.439460      Yes
# 4               4     QA50777      Oregon              9025.067525       No
# ...           ...         ...         ...                      ...      ...
# 10905       10905     FE99816      Nevada             15563.369440       No
# 10906       10906     KX53892      Oregon              5259.444853       No
# 10907       10907     TL39050     Arizona             23893.304100       No
# 10908       10908     WA60547  California             11971.977650       No
# 10909       10909     IV32877         NaN              6857.519928      NaN
#
# ...

# %%
data.plot(x='sales_channel', y='response', style='o')
# Out:
# <AxesSubplot:xlabel='sales_channel'>

# %% [markdown]
# ## 5. Show a plot of the response rate by the total claim amount.

# %%
data
# Out:
#     sales_channel  response
# 0        0.960368  0.836512
# 1        0.530068  0.412103
# 2        0.587988  0.310750
# 3        0.719778  0.153003
# 4        0.052010  0.709324
# 5        0.829088  0.949109
# 6        0.288536  0.345596
# 7        0.913699  0.175878
# 8        0.095616  0.831013
# 9        0.792578  0.831698
# 10       0.094111  0.615005
# 11       0.724528  0.758869
# 12       0.188456  0.850620
# 13       0.362349  0.074998
# 14       0.477100  0.586314
# 15       0.064014  0.520465
# 16       0.285600  0.604306
# 17       0.485498  0.932950
# 18       0.168640  0.146072
# 19       0.063323  0.063898

# %%
data.plot(x='claim_amountl', y='response', style='o')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\invité-1\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'claim_amountl'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# ## 6. Show a plot of the response rate by income.

# %%
data.plot(x='income', y='response', style='o')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-088f3b4a0c02> in <module>
# ----> 1 plt.Scatter(data['Income'], data['Response'])
#       2 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'Scatter'
