# %% [markdown]
# # Lab-customer-analysis-round-2

# %% [markdown]
# For this lab, we will be using the `marketing_customer_analysis.csv` file that you can find in the `files_for_lab` folder. Check out the `files_for_lab/about.md` to get more information if you are using the Online Excel.
#
# **Note**: For the next labs we will be using the same data file. Please save the code, so that you can re-use it later in the labs following this lab.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Show the dataframe shape.

# %%
data = pd.read_csv('marketing_customer_analysis.csv')

# %%
data
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0         Basic   College           2/18/11         Employed      M  ...
# 1         Basic   College           1/18/11       Unemployed      F  ...
# 2         Basic  Bachelor           2/10/11         Employed      M  ...
# 3      Extended   College           1/11/11         Employed      M  ...
# 4       Premium  Bachelor           1/17/11    Medical Leave      F  ...
# ...         ...       ...               ...              ...    ...  ...
# 10905   Premium  Bachelor           1/19/11       Unemployed      F  ...
# 10906     Basic   College            1/6/11         Employed      F  ...
# 10907  Extended  Bachelor            2/6/11         Employed      F  ...
# 10908   Premium   College           2/13/11         Employed      F  ...
# 10909     Basic  Bachelor            1/8/11       Unemployed      M  ...
#
#        Number of Open Complaints Number of Policies     Policy Type  \
# 0                            0.0                  9  Corporate Auto
# 1                            0.0                  1   Personal Auto
# 2                            0.0                  2   Personal Auto
# 3                            0.0                  2  Corporate Auto
# 4                            NaN                  7   Personal Auto
# ...                          ...                ...             ...
# 10905                        NaN                  7   Personal Auto
# 10906                        0.0                  6   Personal Auto
# 10907                        0.0                  2  Corporate Auto
# 10908                        4.0                  6   Personal Auto
# 10909                        0.0                  3   Personal Auto
#
#              Policy  Renew Offer Type  Sales Channel  Total Claim Amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        Vehicle Class Vehicle Size Vehicle Type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [10910 rows x 26 columns]

# %%
data.shape
# Out:
# (10910, 26)

# %% [markdown]
# ## 2. Standardize header names.

# %%
data.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# 0                        0.0                  9  Corporate Auto  Corporate L3
# 1                        0.0                  1   Personal Auto   Personal L3
# 2                        0.0                  2   Personal Auto   Personal L3
# 3                        0.0                  2  Corporate Auto  Corporate L3
# 4                        NaN                  7   Personal Auto   Personal L2
#
#    Renew Offer Type  Sales Channel  Total Claim Amount  Vehicle Class  \
# 0            Offer3          Agent          292.800000  Four-Door Car
# 1            Offer4    Call Center          744.924331  Four-Door Car
# 2            Offer3    Call Center          480.000000            SUV
# 3            Offer2         Branch          484.013411  Four-Door Car
# 4            Offer1         Branch          707.925645  Four-Door Car
#
#   Vehicle Size Vehicle Type
# 0      Medsize          NaN
# 1      Medsize          NaN
# 2      Medsize            A
# 3      Medsize            A
# 4      Medsize          NaN
#
# [5 rows x 26 columns]

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
data = data.rename(columns={'Customer':'Customer ID',
                         'EmploymentStatus': 'Employment Status'})

data
# Out:
#        Unnamed: 0 Customer ID       State  Customer Lifetime Value Response  \
# 0               0     DK49336     Arizona              4809.216960       No
# 1               1     KX64629  California              2228.525238       No
# 2               2     LZ68649  Washington             14947.917300       No
# 3               3     XL78013      Oregon             22332.439460      Yes
# 4               4     QA50777      Oregon              9025.067525       No
# ...           ...         ...         ...                      ...      ...
# 10905       10905     FE99816      Nevada             15563.369440       No
# 10906       10906     KX53892      Oregon              5259.444853       No
# 10907       10907     TL39050     Arizona             23893.304100       No
# 10908       10908     WA60547  California             11971.977650       No
# 10909       10909     IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date Employment Status Gender  ...  \
# 0         Basic   College           2/18/11          Employed      M  ...
# 1         Basic   College           1/18/11        Unemployed      F  ...
# 2         Basic  Bachelor           2/10/11          Employed      M  ...
# 3      Extended   College           1/11/11          Employed      M  ...
# 4       Premium  Bachelor           1/17/11     Medical Leave      F  ...
# ...         ...       ...               ...               ...    ...  ...
# 10905   Premium  Bachelor           1/19/11        Unemployed      F  ...
# 10906     Basic   College            1/6/11          Employed      F  ...
# 10907  Extended  Bachelor            2/6/11          Employed      F  ...
# 10908   Premium   College           2/13/11          Employed      F  ...
# 10909     Basic  Bachelor            1/8/11        Unemployed      M  ...
#
#        Number of Open Complaints Number of Policies     Policy Type  \
# 0                            0.0                  9  Corporate Auto
# 1                            0.0                  1   Personal Auto
# 2                            0.0                  2   Personal Auto
# 3                            0.0                  2  Corporate Auto
# 4                            NaN                  7   Personal Auto
# ...                          ...                ...             ...
# 10905                        NaN                  7   Personal Auto
# 10906                        0.0                  6   Personal Auto
# 10907                        0.0                  2  Corporate Auto
# 10908                        4.0                  6   Personal Auto
# 10909                        0.0                  3   Personal Auto
#
#              Policy  Renew Offer Type  Sales Channel  Total Claim Amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        Vehicle Class Vehicle Size Vehicle Type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [10910 rows x 26 columns]

# %%
cols = []

for i in range(len(data.columns)):
    cols.append(data.columns[i].lower())
    
cols
# Out:
# ['unnamed: 0',
#  'customer id',
#  'state',
#  'customer lifetime value',
#  'response',
#  'coverage',
#  'education',
#  'effective to date',
#  'employment status',
#  'gender',
#  'income',
#  'location code',
#  'marital status',
#  'monthly premium auto',
#  'months since last claim',
#  'months since policy inception',
#  'number of open complaints',
#  'number of policies',
#  'policy type',
#  'policy',
#  'renew offer type',
#  'sales channel',
#  'total claim amount',
#  'vehicle class',
#  'vehicle size',
#  'vehicle type']

# %% [markdown]
# ## 3. Which columns are numerical?

# %%
data_numerics_only = data.select_dtypes(include=np.number)
data_numerics_only
# Out:
#        Unnamed: 0  Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        Months Since Last Claim  Months Since Policy Inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# 2                         34.0                             31
# 3                         10.0                              3
# 4                          NaN                             31
# ...                        ...                            ...
# 10905                      NaN                             40
# 10906                      7.0                             68
# 10907                     11.0                             63
# 10908                      0.0                             27
# 10909                     31.0                              1
#
#        Number of Open Complaints  Number of Policies  Total Claim Amount
# 0                            0.0                   9          292.800000
# 1                            0.0                   1          744.924331
# 2                            0.0                   2          480.000000
# 3                            0.0                   2          484.013411
# 4                            NaN                   7          707.925645
# ...                          ...                 ...                 ...
# 10905                        NaN                   7         1214.400000
# 10906                        0.0                   6          273.018929
# 10907                        0.0                   2          381.306996
# 10908                        4.0                   6          618.288849
# 10909                        0.0                   3         1021.719397
#
# [10910 rows x 9 columns]

# %%
data
# Out:
#        Unnamed: 0 Customer ID       State  Customer Lifetime Value Response  \
# 0               0     DK49336     Arizona              4809.216960       No
# 1               1     KX64629  California              2228.525238       No
# 2               2     LZ68649  Washington             14947.917300       No
# 3               3     XL78013      Oregon             22332.439460      Yes
# 4               4     QA50777      Oregon              9025.067525       No
# ...           ...         ...         ...                      ...      ...
# 10905       10905     FE99816      Nevada             15563.369440       No
# 10906       10906     KX53892      Oregon              5259.444853       No
# 10907       10907     TL39050     Arizona             23893.304100       No
# 10908       10908     WA60547  California             11971.977650       No
# 10909       10909     IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date Employment Status Gender  ...  \
# 0         Basic   College           2/18/11          Employed      M  ...
# 1         Basic   College           1/18/11        Unemployed      F  ...
# 2         Basic  Bachelor           2/10/11          Employed      M  ...
# 3      Extended   College           1/11/11          Employed      M  ...
# 4       Premium  Bachelor           1/17/11     Medical Leave      F  ...
# ...         ...       ...               ...               ...    ...  ...
# 10905   Premium  Bachelor           1/19/11        Unemployed      F  ...
# 10906     Basic   College            1/6/11          Employed      F  ...
# 10907  Extended  Bachelor            2/6/11          Employed      F  ...
# 10908   Premium   College           2/13/11          Employed      F  ...
# 10909     Basic  Bachelor            1/8/11        Unemployed      M  ...
#
#        Number of Open Complaints Number of Policies     Policy Type  \
# 0                            0.0                  9  Corporate Auto
# 1                            0.0                  1   Personal Auto
# 2                            0.0                  2   Personal Auto
# 3                            0.0                  2  Corporate Auto
# 4                            NaN                  7   Personal Auto
# ...                          ...                ...             ...
# 10905                        NaN                  7   Personal Auto
# 10906                        0.0                  6   Personal Auto
# 10907                        0.0                  2  Corporate Auto
# 10908                        4.0                  6   Personal Auto
# 10909                        0.0                  3   Personal Auto
#
#              Policy  Renew Offer Type  Sales Channel  Total Claim Amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        Vehicle Class Vehicle Size Vehicle Type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [10910 rows x 26 columns]

# %% [markdown]
# ## 4. Which columns are categorical?

# %%
data.dtypes
# Out:
# UNNAMED: 0                         int64
# CUSTOMER                          object
# STATE                             object
# CUSTOMER LIFETIME VALUE          float64
# RESPONSE                          object
# COVERAGE                          object
# EDUCATION                         object
# EFFECTIVE TO DATE                 object
# EMPLOYMENTSTATUS                  object
# GENDER                            object
# INCOME                             int64
# LOCATION CODE                     object
# MARITAL STATUS                    object
# MONTHLY PREMIUM AUTO               int64
# MONTHS SINCE LAST CLAIM          float64
# MONTHS SINCE POLICY INCEPTION      int64
# NUMBER OF OPEN COMPLAINTS        float64
# NUMBER OF POLICIES                 int64
# POLICY TYPE                       object
# POLICY                            object
# RENEW OFFER TYPE                  object
# SALES CHANNEL                     object
# TOTAL CLAIM AMOUNT               float64
# VEHICLE CLASS                     object
# VEHICLE SIZE                      object
# VEHICLE TYPE                      object
# dtype: object

# %% [markdown]
# ## 5. Check and deal with `NaN` values.

# %%
data.dropna()
# Out:
#        Unnamed: 0 Customer ID       State  Customer Lifetime Value Response  \
# 2               2     LZ68649  Washington             14947.917300       No
# 3               3     XL78013      Oregon             22332.439460      Yes
# 10             10     HG93801     Arizona              5154.764074       No
# 13             13     KR82385  California              5454.587929       No
# 16             16     FH51383  California              5326.677654       No
# ...           ...         ...         ...                      ...      ...
# 10902       10902     PP30874  California              3579.023825       No
# 10903       10903     SU71163     Arizona              2771.663013       No
# 10904       10904     QI63521      Nevada             19228.463620       No
# 10906       10906     KX53892      Oregon              5259.444853       No
# 10908       10908     WA60547  California             11971.977650       No
#
#        Coverage             Education Effective To Date Employment Status  \
# 2         Basic              Bachelor           2/10/11          Employed
# 3      Extended               College           1/11/11          Employed
# 10     Extended  High School or Below            1/2/11          Employed
# 13        Basic                Master           1/26/11          Employed
# 16        Basic  High School or Below            2/7/11          Employed
# ...         ...                   ...               ...               ...
# 10902  Extended  High School or Below           1/24/11          Employed
# 10903     Basic               College            1/7/11          Employed
# 10904     Basic  High School or Below           2/24/11        Unemployed
# 10906     Basic               College            1/6/11          Employed
# 10908   Premium               College           2/13/11          Employed
#
#       Gender  ...  Number of Open Complaints Number of Policies  \
# 2          M  ...                        0.0                  2
# 3          M  ...                        0.0                  2
# 10         M  ...                        0.0                  1
# 13         M  ...                        0.0                  4
# 16         F  ...                        0.0                  6
# ...      ...  ...                        ...                ...
# 10902      F  ...                        2.0                  1
# 10903      M  ...                        4.0                  1
# 10904      M  ...                        0.0                  2
# 10906      F  ...                        0.0                  6
# 10908      F  ...                        4.0                  6
#
#           Policy Type        Policy  Renew Offer Type  Sales Channel  \
# 2       Personal Auto   Personal L3            Offer3    Call Center
# 3      Corporate Auto  Corporate L3            Offer2         Branch
# 10     Corporate Auto  Corporate L3            Offer2         Branch
# 13      Personal Auto   Personal L3            Offer4    Call Center
# 16      Personal Auto   Personal L3            Offer4    Call Center
# ...               ...           ...               ...            ...
# 10902   Personal Auto   Personal L2            Offer2          Agent
# 10903   Personal Auto   Personal L2            Offer2         Branch
# 10904   Personal Auto   Personal L2            Offer1         Branch
# 10906   Personal Auto   Personal L3            Offer2         Branch
# 10908   Personal Auto   Personal L1            Offer1         Branch
#
#        Total Claim Amount  Vehicle Class Vehicle Size Vehicle Type
# 2              480.000000            SUV      Medsize            A
# 3              484.013411  Four-Door Car      Medsize            A
# 10             442.521087            SUV        Large            A
# 13             331.200000   Two-Door Car      Medsize            A
# 16             300.528579   Two-Door Car        Large            A
# ...                   ...            ...          ...          ...
# 10902          655.200000  Four-Door Car      Medsize            A
# 10903          355.200000   Two-Door Car      Medsize            A
# 10904          897.600000     Luxury SUV      Medsize            A
# 10906          273.018929  Four-Door Car      Medsize            A
# 10908          618.288849            SUV      Medsize            A
#
# [4543 rows x 26 columns]

# %% [markdown]
# ## 6. Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. _Hint_: If data from March does not exist, consider only January and February.

# %%
data['month'] = pd.DatetimeIndex(data['Effective To Date']).month

data.head()
# Out:
#                    Unnamed: 0 Customer ID       State  \
# Effective To Date
# 2/18/11                     0     DK49336     Arizona
# 1/18/11                     1     KX64629  California
# 2/10/11                     2     LZ68649  Washington
# 1/11/11                     3     XL78013      Oregon
# 1/17/11                     4     QA50777      Oregon
#
#                    Customer Lifetime Value Response  Coverage Education  \
# Effective To Date
# 2/18/11                        4809.216960       No     Basic   College
# 1/18/11                        2228.525238       No     Basic   College
# 2/10/11                       14947.917300       No     Basic  Bachelor
# 1/11/11                       22332.439460      Yes  Extended   College
# 1/17/11                        9025.067525       No   Premium  Bachelor
#
#                   Effective To Date Employment Status Gender  ...  \
# Effective To Date                                             ...
# 2/18/11                     2/18/11          Employed      M  ...
# 1/18/11                     1/18/11        Unemployed      F  ...
# 2/10/11                     2/10/11          Employed      M  ...
# 1/11/11                     1/11/11          Employed      M  ...
# 1/17/11                     1/17/11     Medical Leave      F  ...
#
#                    Number of Policies     Policy Type        Policy  \
# Effective To Date
# 2/18/11                             9  Corporate Auto  Corporate L3
# 1/18/11                             1   Personal Auto   Personal L3
# 2/10/11                             2   Personal Auto   Personal L3
# 1/11/11                             2  Corporate Auto  Corporate L3
# 1/17/11                             7   Personal Auto   Personal L2
#
#                    Renew Offer Type  Sales Channel  Total Claim Amount  \
# Effective To Date
# 2/18/11                      Offer3          Agent          292.800000
# 1/18/11                      Offer4    Call Center          744.924331
# 2/10/11                      Offer3    Call Center          480.000000
# 1/11/11                      Offer2         Branch          484.013411
# 1/17/11                      Offer1         Branch          707.925645
#
#                    Vehicle Class  Vehicle Size Vehicle Type month
# Effective To Date
# 2/18/11            Four-Door Car       Medsize          NaN     2
# 1/18/11            Four-Door Car       Medsize          NaN     1
# 2/10/11                      SUV       Medsize            A     2
# 1/11/11            Four-Door Car       Medsize            A     1
# 1/17/11            Four-Door Car       Medsize          NaN     1
#
# [5 rows x 27 columns]

# %%
data.loc[(data['month'] >= 1) & (data['month'] <= 2)]
# Out:
#                    Unnamed: 0 Customer ID       State  \
# Effective To Date
# 2/18/11                     0     DK49336     Arizona
# 1/18/11                     1     KX64629  California
# 2/10/11                     2     LZ68649  Washington
# 1/11/11                     3     XL78013      Oregon
# 1/17/11                     4     QA50777      Oregon
# ...                       ...         ...         ...
# 1/19/11                 10905     FE99816      Nevada
# 1/6/11                  10906     KX53892      Oregon
# 2/6/11                  10907     TL39050     Arizona
# 2/13/11                 10908     WA60547  California
# 1/8/11                  10909     IV32877         NaN
#
#                    Customer Lifetime Value Response  Coverage Education  \
# Effective To Date
# 2/18/11                        4809.216960       No     Basic   College
# 1/18/11                        2228.525238       No     Basic   College
# 2/10/11                       14947.917300       No     Basic  Bachelor
# 1/11/11                       22332.439460      Yes  Extended   College
# 1/17/11                        9025.067525       No   Premium  Bachelor
# ...                                    ...      ...       ...       ...
# 1/19/11                       15563.369440       No   Premium  Bachelor
# 1/6/11                         5259.444853       No     Basic   College
# 2/6/11                        23893.304100       No  Extended  Bachelor
# 2/13/11                       11971.977650       No   Premium   College
# 1/8/11                         6857.519928      NaN     Basic  Bachelor
#
#                   Effective To Date Employment Status Gender  ...  \
# Effective To Date                                             ...
# 2/18/11                     2/18/11          Employed      M  ...
# 1/18/11                     1/18/11        Unemployed      F  ...
# 2/10/11                     2/10/11          Employed      M  ...
# 1/11/11                     1/11/11          Employed      M  ...
# 1/17/11                     1/17/11     Medical Leave      F  ...
# ...                             ...               ...    ...  ...
# 1/19/11                     1/19/11        Unemployed      F  ...
# 1/6/11                       1/6/11          Employed      F  ...
# 2/6/11                       2/6/11          Employed      F  ...
# 2/13/11                     2/13/11          Employed      F  ...
# 1/8/11                       1/8/11        Unemployed      M  ...
#
#                    Number of Policies     Policy Type        Policy  \
# Effective To Date
# 2/18/11                             9  Corporate Auto  Corporate L3
# 1/18/11                             1   Personal Auto   Personal L3
# 2/10/11                             2   Personal Auto   Personal L3
# 1/11/11                             2  Corporate Auto  Corporate L3
# 1/17/11                             7   Personal Auto   Personal L2
# ...                               ...             ...           ...
# 1/19/11                             7   Personal Auto   Personal L1
# 1/6/11                              6   Personal Auto   Personal L3
# 2/6/11                              2  Corporate Auto  Corporate L3
# 2/13/11                             6   Personal Auto   Personal L1
# 1/8/11                              3   Personal Auto   Personal L1
#
#                    Renew Offer Type  Sales Channel  Total Claim Amount  \
# Effective To Date
# 2/18/11                      Offer3          Agent          292.800000
# 1/18/11                      Offer4    Call Center          744.924331
# 2/10/11                      Offer3    Call Center          480.000000
# 1/11/11                      Offer2         Branch          484.013411
# 1/17/11                      Offer1         Branch          707.925645
# ...                             ...            ...                 ...
# 1/19/11                      Offer3            Web         1214.400000
# 1/6/11                       Offer2         Branch          273.018929
# 2/6/11                       Offer1            Web          381.306996
# 2/13/11                      Offer1         Branch          618.288849
# 1/8/11                       Offer4            Web         1021.719397
#
#                    Vehicle Class  Vehicle Size Vehicle Type month
# Effective To Date
# 2/18/11            Four-Door Car       Medsize          NaN     2
# 1/18/11            Four-Door Car       Medsize          NaN     1
# 2/10/11                      SUV       Medsize            A     2
# 1/11/11            Four-Door Car       Medsize            A     1
# 1/17/11            Four-Door Car       Medsize          NaN     1
# ...                          ...           ...          ...   ...
# 1/19/11               Luxury Car       Medsize            A     1
# 1/6/11             Four-Door Car       Medsize            A     1
# 2/6/11                Luxury SUV       Medsize          NaN     2
# 2/13/11                      SUV       Medsize            A     2
# 1/8/11                       SUV       Medsize          NaN     1
#
# [10910 rows x 27 columns]

# %% [markdown]
# ## 7. Put all the previously mentioned data transformations into a function.

# %%
def : DateQuarter  
    if data['month'] = pd.DatetimeIndex(data['Effective To Date']).month
    
    elif data.loc[(data['month'] >= 1) & (data['month'] <= 2)]
    
    data
# Out:
#   File "<ipython-input-70-dd51e923f4d3>", line 1
#     def : DateQuarter
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 8. BONUS

# %% [markdown]
# ### 8.1. List Comprehensions

# %% [markdown]
# #### 8.1.1 Find the capital letters (and not white space) in the sentence 'The Quick Brown Fox Jumped Over The Lazy Dog'.

# %% [markdown]
# #### 8.1.2. Use a list comprehension to create a list with the same elements rounded to 2 decimal positions.

# %%
a = [
    0.84062117, 0.48006452, 0.7876326 , 0.77109654,
    0.44409793, 0.09014516, 0.81835917, 0.87645456,
    0.7066597 , 0.09610873, 0.41247947, 0.57433389,
    0.29960807, 0.42315023, 0.34452557, 0.4751035 ,
    0.17003563, 0.46843998, 0.92796258, 0.69814654,
    0.41290051, 0.19561071, 0.16284783, 0.97016248,
    0.71725408, 0.87702738, 0.31244595, 0.76615487,
    0.20754036, 0.57871812, 0.07214068, 0.40356048,
    0.12149553, 0.53222417, 0.9976855 , 0.12536346,
    0.80930099, 0.50962849, 0.94555126, 0.33364763
]

# %% [markdown]
# ### 8.2. Lambdas

# %% [markdown]
# #### 8.2.1. Using Lambda Expressions in List Comprehensions

# %% [markdown]
# In the following challenge, we will combine two lists using a lambda expression in a list comprehension.
#
# To do this, we will need to introduce the zip function. The zip function returns an iterator of tuples.
#
# The way zip function works with list has been shown below:

# %% [markdown]
# In this exercise we will try to compare the elements on the same index in the two lists. We want to zip the two lists and then use a lambda expression to compare if: list1 element > list2 element
